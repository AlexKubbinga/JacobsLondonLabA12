# %%
import pandas as pd
import requests

url = "https://www.dreso.com/de/en/career/job-opportunities"




# In[ ]:

# %%
r = requests.get(url)

# %%
df_list = pd.read_html(r.text) # this parses all the tables in webpages to a list

# %%
df = df_list[0]
df = df.iloc[1: , :]
df = df.iloc[:-1 , :]
df.head()


# In[20]:
# Out:
#                                          Entry level  \
# 1  Innenarchitekt / Architekt (w/m/d) als Projekt...
# 2  Architekt/Innenarchitekt (w/m/d) als Teamlead ...
# 3                   Praktikant (w/m/d) Baumanagement
# 4              Teamassistenz (w/m/d) User Experience
# 5  Ingenieur (w/m/d) für Energiedesign, CO₂-Optim...
#
#                                           Field  Country               City  \
# 1  Workplace Consulting | Consulting | Planning  Germany          Frankfurt
# 2  Workplace Consulting | Consulting | Planning  Germany  Baden-Württemberg
# 3                       Construction Management  Germany             Munich
# 4             Workplace Consulting | Assistance  Germany          Stuttgart
# 5                        Engineering Consulting  Germany          Stuttgart
#
#                 Time limit Corporate group                  Entry as
# 1  Full-time and Part-time  Drees & Sommer  Experienced professional
# 2                Full-time  Drees & Sommer  Experienced professional
# 3                Full-time  Drees & Sommer                  Students
# 4                Full-time  Drees & Sommer  Experienced professional
# 5                Full-time  Drees & Sommer  Experienced professional

# %%
# Importing the required libraries
import requests
import pandas as pd
from bs4 import BeautifulSoup


# In[21]:


# Downloading contents of the web page
url = "https://www.dreso.com/de/en/career/job-opportunities"
data = requests.get(url).text


# In[22]:


# Creating BeautifulSoup object
soup = BeautifulSoup(data, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-de">
#  <head>
#   <meta charset="utf-8"/>
#   <!--
# 	This website is powered by TYPO3 - inspiring people to share!
# 	TYPO3 is a free open source Content Management Framework initially created by Kasper Skaarhoj and licensed under GNU/GPL.
# 	TYPO3 is copyright 1998-2022 of Kasper Skaarhoj. Extensions are copyright of their respective owners.
# 	Information and contribution at https://typo3.org/
# -->
#   <title>
#    Job opportunities | Drees &amp; Sommer
#   </title>
#   <meta content="TYPO3 CMS" name="generator">
#    <meta content="Here you can find all job offers. We are looking forward to your application!" name="description"/>
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
#    <meta content="https://www.dreso.com/fileadmin/_processed_/3/5/csm_Header_YOUDECIDE_Umantis_YP_Desktop_7b8e4875c6.jpg" property="og:image"/>
#    <meta content="https://www.dreso.com/fileadmin/_processed_/3/5/csm_Header_YOUDECIDE_Umantis_YP_Desktop_7b8e4875c6.jpg" property="og:image:url"/>
#    <meta content="840" property="og:image:width"/>
#    <meta content="439" property="og:image:height"/>
#    <meta content="[Translate to English:] " property="og:image:alt"/>
#    <meta content="summary" name="twitter:card"/>
#    <link href="/typo3temp/assets/compressed/merged-b384169ed3a82cdfb2b254f9e20c8cae.css?1650447413" media="all" rel="stylesheet" type="text/css"/>
#    <meta content="Drees &amp; Sommer" name="application-name"/>
#    <meta content="yes" name="mobile-web-app-capable"/>
#    <meta content="yes" name="apple-mobile-web-app-capable"/>
#    <meta content="Drees &amp; Sommer" name="apple-mobile-web-app-title"/>
#    <meta content="#002965" name="msapplication-TileColor"/>
#    <meta content="#002965" name="theme-color"/>
#    <meta content="#002965" name="apple-mobile-web-app-status-bar-style"/>
#    <meta content="browserconfig.xml?v=200925084922" name="msapplication-config"/>
#    <link href="/typo3conf/ext/dreso/Resources/Public/favicon/Favicon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="//app.usercentrics.eu" rel="preconnect"/>
#    <link href="//api.usercentrics.eu" rel="preconnect"/>
#    <link as="script" href="//app.usercentrics.eu/browser-ui/latest/loader.js" rel="preload"/>
#    <link href="//privacy-proxy.usercentrics.eu" rel="preconnect"/>
#    <link as="script" href="//privacy-proxy.usercentrics.eu/latest/uc-block.bundle.js" rel="preload"/>
#    <script async="" data-settings-id="p9uYSRHDt" id="usercentrics-cmp" src="https://app.usercentrics.eu/browser-ui/latest/loader.js">
#    </script>
#    <script src="https://privacy-proxy.usercentrics.eu/latest/uc-block.bundle.js" type="application/javascript">
#    </script>
#    <!-- Google Tag Manager -->
#    <script data-usercentrics="Google Tag Manager" type="text/plain">
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-PHNKD8F');
#    </script>
#    <!-- End Google Tag Manager -->
#    <script data-usercentrics="MyFonts Counter" type="text/plain">
#     var head  = document.getElementsByTagName('head')[0];
#           var linkOne  = document.createElement('link');
#           var linkTwo  = document.createElement('link');
#
#           linkOne.rel  = 'stylesheet';
#           linkOne.type = 'text/css';
#           linkOne.href = '//hello.myfonts.net/count/39ae3a';
#
#           head.appendChild(linkOne);
#
#           linkTwo.rel  = 'stylesheet';
#           linkTwo.type = 'text/css';
#           linkTwo.href = '//hello.myfonts.net/count/32ea90';
#
#           head.appendChild(linkTwo);
#    </script>
#    <link href="//www.dreso.com/de/karriere/stellenangebote" hreflang="de-de" rel="alternate">
#     <link href="//www.dreso.com/de/en/career/job-opportunities" hreflang="en-de" rel="alternate">
#      <link href="//www.dreso.com/de/karriere/stellenangebote" hreflang="x-default" rel="alternate">
#       <link href="http://www.dreso.com/de/en/career/job-opportunities" rel="canonical">
#       </link>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PHNKD8F" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <header id="header">
#    <div class="head__container">
#     <div class="head__section-left">
#      <a href="/de/en/" id="logo">
#       <img alt="" border="0" height="26" src="/typo3conf/ext/dreso/Resources/Public/dreso-logo.svg" width="86"/>
#      </a>
#     </div>
#     <div class="head__section-right">
#      <div class="breadcrumb_container">
#       <nav class="navigation" id="breadcrumb-navigation">
#        <ul>
#         <li>
#          <a href="/de/en/career" title="Career">
#           Career
#          </a>
#         </li>
#         <li class="active">
#          Job opportunities
#         </li>
#        </ul>
#       </nav>
#      </div>
#      <button class="head__button" data-target="countries_container" id="countries" name="showcountries" type="button">
#       <span class="icon-country">
#       </span>
#      </button>
#      <button class="head__button" data-target="lang_container" id="lang" name="showlang" type="button">
#       <span>
#        en
#       </span>
#      </button>
#      <button class="head__button" data-target="search_container" id="search" name="showsearch" type="button">
#       <span class="icon-search">
#       </span>
#      </button>
#      <button class="head__button" data-target="nav_container" id="nav" name="shownav" type="button">
#       <span class="icon-menu">
#       </span>
#      </button>
#     </div>
#    </div>
#    <div class="overlay_container">
#     <div class="countries_container">
#      <div class="container">
#       <div class="row">
#        <div class="col-12 col-lg-4">
#         <div class="lang-intro">
#          <span class="icon-country">
#          </span>
#          <span class="h3 light normal headline">
#           International Sites
#          </span>
#         </div>
#        </div>
#        <div class="col-12 col-md-6 col-lg-4">
#         <div class="select_container">
#          <span class="select-button">
#           Country
#          </span>
#         </div>
#         <div class="country_container navigation sublist">
#          <ul>
#           <li class="" id="lang-at">
#            <button>
#             <a href="https://www.dreso.com/at/">
#              Austria
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-apac">
#            <button>
#             <a href="https://www.dreso.com/apac/">
#              Asia Pacific
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-be">
#            <button>
#             <a href="https://www.dreso.com/be/">
#              Belgium
#             </a>
#            </button>
#           </li>
#           <li id="lang-cn">
#            <a href="https://www.dreso.cn/zh-CN/" target="_blank">
#             China
#            </a>
#           </li>
#           <li id="lang-dk">
#            <button>
#             <a href="https://www.dreso.com/nordic/">
#              Denmark
#             </a>
#            </button>
#           </li>
#           <li id="lang-fi">
#            <button>
#             <a href="https://www.dreso.com/nordic/">
#              Finland
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-fr">
#            <button>
#             <a href="https://www.dreso.com/fr/">
#              France
#             </a>
#            </button>
#           </li>
#           <li class="selected" id="lang-de">
#            <button>
#             <a href="https://www.dreso.com/de/">
#              Germany
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-hu">
#            <button>
#             <a href="https://www.dreso.com/hu/">
#              Hungary
#             </a>
#            </button>
#           </li>
#           <li id="lang-it">
#            <button>
#             <a href="https://www.dreso.com/it/">
#              Italy
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-lu">
#            <button>
#             <a href="https://www.dreso.com/lu/">
#              Luxembourg
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-nl">
#            <button>
#             <a href="https://www.dreso.com/nl/">
#              Netherlands
#             </a>
#            </button>
#           </li>
#           <li id="lang-no">
#            <button>
#             <a href="https://www.dreso.com/nordic/">
#              Norway
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-nord">
#            <button>
#             <a href="https://www.dreso.com/nordic/">
#              Nordic
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-ru">
#            <button>
#             <a href="https://www.dreso.ru/ru/">
#              Russia
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-es">
#            <button>
#             <a href="https://www.dreso.com/es/">
#              Spain
#             </a>
#            </button>
#           </li>
#           <li id="lang-se">
#            <button>
#             <a href="https://www.dreso.com/nordic/">
#              Sweden
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-ch">
#            <button>
#             <a href="https://www.dreso.com/ch/">
#              Switzerland
#             </a>
#            </button>
#           </li>
#           <li class="" id="lang-gb">
#            <button>
#             <a href="https://www.dreso.com/uk/">
#              United Kingdom
#             </a>
#            </button>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="lang_container">
#      <div class="container">
#       <div class="row">
#        <div class="col-12 col-lg-4">
#         <div class="lang-intro">
#          <span class="h3 light normal headline">
#           Language options
#          </span>
#         </div>
#        </div>
#        <div class="col-12 col-md-6 col-lg-4">
#         <div class="language_container navigation sublist">
#          <ul class="selected" data-lang="lang-de">
#           <li class="">
#            <a href="/de/karriere/stellenangebote" hreflang="de-de" title="Deutsch">
#             Deutsch
#            </a>
#           </li>
#           <li class="active">
#            <a href="/de/en/career/job-opportunities" hreflang="en-de" title="English">
#             English
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="search_container">
#      <div class="container">
#       <div class="row">
#        <div class="col-12 col-md-8 col-lg-6">
#         <div class="search-intro">
#          <span class="h3 normal headline">
#           Search
#          </span>
#         </div>
#         <div class="tx_solr container p-0">
#          <div class="row">
#           <div class="col-12 col-md-12">
#            <div class="djl tx-solr-search-form">
#             <form accept-charset="utf-8" action="/de/en/search" class="search__form search__bar" data-suggest="/de/en/search?type=7384" data-suggest-header="Top Results" id="search-form" method="get">
#              <div class="formbody">
#               <div class="widget widget__text widget-autocomplete f-grow fd-row">
#                <input class="text tx-solr-q js-solr-q tx-solr-suggest tx-solr-suggest-focus form-control px-0 text-uppercase text-white rounded-0 bg-transparent" id="search-bar-q" name="tx_solr[q]" placeholder="" type="text" value=""/>
#               </div>
#               <div class="widget widget__submit">
#                <button class="button submit" name="button" type="submit">
#                 <span class="dyn-arrow">
#                 </span>
#                </button>
#               </div>
#              </div>
#             </form>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="nav_container">
#      <nav class="navigation" id="main-navigation">
#       <div class="container">
#        <div class="sublevel level_1">
#         <ul class="level_1">
#          <li class="level_1 submenu">
#           <a class="level_1 dreso-plus" href="/de/en/dreso">
#           </a>
#           <span class="sub-toggler icon-arrow_forward">
#           </span>
#           <div class="sublevel level_2">
#            <ul class="level_2">
#             <li class="level_2">
#              <a class="level_2" href="/de/en/dreso/sustainable" hreflang="" target="" title="Sustainable">
#               Sustainable
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/dreso/digital" hreflang="" target="" title="Digital">
#               Digital
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/dreso/innovative" hreflang="" target="" title="Innovative">
#               Innovative
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/dreso/economic" hreflang="" target="" title="Economic">
#               Economic
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="level_1 submenu">
#           <a class="level_1" href="/de/en/aspiration">
#            Aspiration
#           </a>
#           <span class="sub-toggler icon-arrow_forward">
#           </span>
#           <div class="sublevel level_2">
#            <ul class="level_2">
#             <li class="level_2">
#              <a class="level_2" href="/de/en/aspiration/successful-buildings" hreflang="" target="" title="Successful Buildings">
#               Successful Buildings
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/aspiration/liveable-cities" hreflang="" target="" title="Liveable cities">
#               Liveable cities
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/aspiration/high-yield-portfolios" hreflang="" target="" title="High-yield portfolios">
#               High-yield portfolios
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/aspiration/powerful-infrastructure" hreflang="" target="" title="Powerful infrastructure">
#               Powerful infrastructure
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/aspiration/future-oriented-consulting" hreflang="" target="" title="Future-oriented consulting">
#               Future-oriented consulting
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="level_1 submenu">
#           <a class="level_1" href="/de/en/sectors">
#            Sectors
#           </a>
#           <span class="sub-toggler icon-arrow_forward">
#           </span>
#           <div class="sublevel level_2">
#            <ul class="level_2">
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/automotive" hreflang="" target="" title="Automotive">
#               Automotive
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/aviation-aerospace" hreflang="" target="" title="Aviation Aerospace">
#               Aviation Aerospace
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/education-science-research" hreflang="" target="" title="Education, Science, Research">
#               Education, Science, Research
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/branchen/chemicals" hreflang="" target="" title="Chemicals">
#               Chemicals
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/energy" hreflang="" target="" title="Energy">
#               Energy
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/branches/healthcare" hreflang="" target="" title="Healthcare">
#               Healthcare
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/hospitality" hreflang="" target="" title="Hospitality">
#               Hospitality
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/industry" hreflang="" target="" title="Industry">
#               Industry
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/information-and-communication-technology-ict" hreflang="" target="" title="Information and Communication Technology (ICT)">
#               Information and Communication Technology (ICT)
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/life-sciences-pharma" hreflang="" target="" title="Life Sciences, Pharma">
#               Life Sciences, Pharma
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/logistics" hreflang="" target="" title="Logistics">
#               Logistics
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/public-sector" hreflang="" target="" title="Public Sector">
#               Public Sector
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/property-companies" hreflang="" target="" title="Property Companies">
#               Property Companies
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/public-transport" hreflang="" target="" title="Public Transport">
#               Public Transport
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/retail" hreflang="" target="" title="Retail">
#               Retail
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/sectors/residential-properties" hreflang="" target="" title="Residential Properties">
#               Residential Properties
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="level_1">
#           <a class="level_1" href="/de/en/expertise">
#            Expertise
#           </a>
#          </li>
#          <li class="level_1">
#           <a class="level_1" href="/de/en/news">
#            News
#           </a>
#          </li>
#          <li class="level_1">
#           <a class="level_1" href="/de/en/projects">
#            Projects
#           </a>
#          </li>
#          <li class="level_1 submenu">
#           <a class="level_1" href="/de/en/company">
#            Company
#           </a>
#           <span class="sub-toggler icon-arrow_forward">
#           </span>
#           <div class="sublevel level_2">
#            <ul class="level_2">
#             <li class="level_2 submenu">
#              <a class="level_2" href="/de/en/company/about" hreflang="" target="" title="About">
#               About
#              </a>
#              <span class="sub-toggler icon-arrow_forward">
#              </span>
#              <div class="sublevel level_3">
#               <ul class="level_3">
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/facts-and-figures" hreflang="" target="" title="Facts and figures">
#                  Facts and figures
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/locations" hreflang="" target="" title="Locations">
#                  Locations
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/corporate-management" hreflang="" target="" title="Corporate Management">
#                  Corporate Management
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/the-blue-way" hreflang="" target="" title="the blue way">
#                  the blue way
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/philosophy" hreflang="" target="" title="Philosophy">
#                  Philosophy
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/shareholdings" hreflang="" target="" title="Shareholdings">
#                  Shareholdings
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/cooperation" hreflang="" target="" title="Cooperation">
#                  Cooperation
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/about/history-of-drees-sommer" hreflang="" target="" title="History of Drees &amp; Sommer">
#                  History of Drees &amp; Sommer
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li class="level_2 submenu">
#              <a class="level_2" href="/de/en/company/press" hreflang="" target="" title="Press">
#               Press
#              </a>
#              <span class="sub-toggler icon-arrow_forward">
#              </span>
#              <div class="sublevel level_3">
#               <ul class="level_3">
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/press/contact" hreflang="" target="" title="Contact">
#                  Contact
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/press/press-releases" hreflang="" target="" title="Press releases">
#                  Press releases
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/press/drees-sommer-at-a-glance" hreflang="" target="" title="Drees &amp; Sommer at a glance">
#                  Drees &amp; Sommer at a glance
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/press/media-center" hreflang="" target="" title="Media Center">
#                  Media Center
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/press/press-e-mail-service" hreflang="" target="" title="Press E-mail service">
#                  Press E-mail service
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li class="level_2 submenu">
#              <a class="level_2" href="/de/en/company/events" hreflang="" target="" title="Events">
#               Events
#              </a>
#              <span class="sub-toggler icon-arrow_forward">
#              </span>
#              <div class="sublevel level_3">
#               <ul class="level_3">
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/company/events/event-formats" hreflang="" target="" title="Event-Formats">
#                  Event-Formats
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="level_1 submenu">
#           <a class="level_1" href="/de/en/career">
#            Career
#           </a>
#           <span class="sub-toggler icon-arrow_forward">
#           </span>
#           <div class="sublevel level_2">
#            <ul class="level_2">
#             <li class="level_2">
#              <a class="level_2" href="/de/en/career/what-sets-us-apart" hreflang="" target="" title="What sets us apart">
#               What sets us apart
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/career/what-we-offer" hreflang="" target="" title="What we offer">
#               What we offer
#              </a>
#             </li>
#             <li class="level_2 submenu">
#              <a class="level_2" href="/de/en/career/what-we-do" hreflang="" target="" title="What we do">
#               What we do
#              </a>
#              <span class="sub-toggler icon-arrow_forward">
#              </span>
#              <div class="sublevel level_3">
#               <ul class="level_3">
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/what-we-do/consulting" hreflang="" target="" title="Consulting">
#                  Consulting
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/what-we-do/project-management" hreflang="" target="" title="Project Management">
#                  Project Management
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/what-we-do/planning" hreflang="" target="" title="Planning">
#                  Planning
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/what-we-do/construction-management" hreflang="" target="" title="Construction Management">
#                  Construction Management
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/what-we-do/sales-management" hreflang="" target="" title="Sales Management">
#                  Sales Management
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/what-we-do/corporate-units" hreflang="" target="" title="Corporate Units">
#                  Corporate Units
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/what-we-do/business-support" hreflang="" target="" title="Business Support">
#                  Business Support
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li class="level_2 submenu">
#              <a class="level_2" href="/de/en/career/career" hreflang="" target="" title="Career">
#               Career
#              </a>
#              <span class="sub-toggler icon-arrow_forward">
#              </span>
#              <div class="sublevel level_3">
#               <ul class="level_3">
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/career/pupils" hreflang="" target="" title="Pupils">
#                  Pupils
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/career/students" hreflang="" target="" title="Students">
#                  Students
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/career/young-professionals" hreflang="" target="" title="Young Professionals">
#                  Young Professionals
#                 </a>
#                </li>
#                <li class="level_3">
#                 <a class="level_3" href="/de/en/career/career/professionals" hreflang="" target="" title="Professionals">
#                  Professionals
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/career/job-opportunities" hreflang="" target="" title="Job opportunities">
#               Job opportunities
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/career/application" hreflang="" target="" title="Application">
#               Application
#              </a>
#             </li>
#             <li class="level_2">
#              <a class="level_2" href="/de/en/career/contact" hreflang="" target="" title="Contact">
#               Contact
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="level_1">
#           <a class="level_1" href="/de/en/company/press">
#            Press
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </nav>
#      <nav class="navigation" id="meta-navigation">
#       <ul>
#        <li class="level_1">
#         <a href="/de/en/company/press">
#          Press
#         </a>
#        </li>
#        <li class="level_1">
#         <a href="/de/en/contact">
#          Contact
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <nav class="navigation" id="social-navigation">
#       <div class="social">
#        <span class="h6 headline">
#         Follow us
#        </span>
#        <ul>
#         <li>
#          <a class="icon-xing" href="https://www.xing.com/companies/dreesundsommer" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="icon-linkedin" href="https://www.linkedin.com/company/drees-&amp;-sommer" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="icon-youtube" href="https://www.youtube.com/channel/UCsGLLBudvpi0TRvRaX0x0zg" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="icon-instagram" href="https://www.instagram.com/drees_sommer/" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="icon-twitter" href="https://twitter.com/drees_sommer" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="icon-vimeo" href="https://vimeo.com/user55605773" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="icon-blog" href="https://dreso-blog.de/" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="icon-podcast" href="/de/en/landing-pages/podcast">
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#     </div>
#    </div>
#   </header>
#   <!--TYPO3SEARCH_begin-->
#   <main class="page-color-default" id="main">
#    <section class="container-fluid px-0" id="c1631">
#     <div class="row">
#      <div class="col-12">
#       <div class="ce_pageheader block">
#        <div class="pageheader__item pageheader__item-overlay">
#         <div class="box_container" style="background-image:url(/fileadmin/_processed_/6/1/csm_YOU_DECIDE_Web_Slide_01_436fff3b7e.jpg)">
#          <div class="container">
#           <h1 class="ce_headline block">
#            Job opportunities
#           </h1>
#          </div>
#         </div>
#         <div class="nav_container navigation__tape navigation">
#          <nav class="rel-page-color">
#           <ul class="level_1">
#            <li class="level_1 root">
#             <a class="root-page" href="/de/en/career">
#              Career
#             </a>
#             <button class="btn btn-toogle">
#              <i class="icon-keyboard_arrow_down">
#              </i>
#             </button>
#            </li>
#            <li class="level_1">
#             <a class="level_1" data-toggle="" href="/de/en/career/what-sets-us-apart">
#              What sets us apart
#             </a>
#            </li>
#            <li class="level_1">
#             <a class="level_1" data-toggle="" href="/de/en/career/what-we-offer">
#              What we offer
#             </a>
#            </li>
#            <li class="level_1 submenu">
#             <a class="level_1" data-toggle="sub" href="/de/en/career/what-we-do">
#              What we do
#             </a>
#             <ul class="level_2">
#              <li class="level_2 nav__helper">
#               <a class="level_2" href="#">
#                <i class="icon-arrow_forward">
#                </i>
#               </a>
#               <button class="btn btn-close">
#               </button>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/what-we-do/consulting">
#                Consulting
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/what-we-do/project-management">
#                Project Management
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/what-we-do/planning">
#                Planning
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/what-we-do/construction-management">
#                Construction Management
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/what-we-do/sales-management">
#                Sales Management
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/what-we-do/corporate-units">
#                Corporate Units
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/what-we-do/business-support">
#                Business Support
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="level_1 submenu">
#             <a class="level_1" data-toggle="sub" href="/de/en/career/career">
#              Career
#             </a>
#             <ul class="level_2">
#              <li class="level_2 nav__helper">
#               <a class="level_2" href="#">
#                <i class="icon-arrow_forward">
#                </i>
#               </a>
#               <button class="btn btn-close">
#               </button>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/career/pupils">
#                Pupils
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/career/students">
#                Students
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/career/young-professionals">
#                Young Professionals
#               </a>
#              </li>
#              <li class="level_2">
#               <a class="level_2" href="/de/en/career/career/professionals">
#                Professionals
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="level_1 selected">
#             <a class="level_1" data-toggle="selected current" href="/de/en/career/job-opportunities">
#              Job opportunities
#             </a>
#            </li>
#            <li class="level_1">
#             <a class="level_1" data-toggle="" href="/de/en/career/application">
#              Application
#             </a>
#            </li>
#            <li class="level_1">
#             <a class="level_1" data-toggle="" href="/de/en/career/contact">
#              Contact
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section class="container frame-space-after-none" id="c1876">
#     <div class="row m12">
#      <div class="col-12 d-flex justify-content-center">
#       <a class="link__cta link__cta-light-grey" href="https://recruitingapp-5045.de.umantis.com/Vacancies/InitiativeApplication/31?lang=eng" target="_blank">
#        Unsolicited application
#       </a>
#      </div>
#     </div>
#    </section>
#    <section class="container frame-space-before-extra-small frame-space-after-extra-large" id="c1875">
#     <div class="row m12">
#      <div class="col-12 d-flex justify-content-center">
#       <a class="link__cta link__cta-light-grey" href="https://recruitingapp-5045.de.umantis.com/Vacancies/Register/31" target="_blank">
#        Job alert
#       </a>
#      </div>
#     </div>
#    </section>
#    <section class="container" id="c234">
#     <div class="row">
#      <div class="col-12">
#       <div class="frame frame-default frame-type-list">
#        <a id="c3377">
#        </a>
#        <section class="container jobs">
#         <div class="row">
#          <div class="col-12">
#           <div class="mod_searchnavigation">
#            <div class="filternav__searchbar search__bar col-12 col-md-8 offset-md-2">
#             <div class="widget widget__text widget-autocomplete f-grow fd-row">
#              <input class="text checkbox autocomplete" data-group="jobs" data-id="search" data-jplist-control="textbox-filter" data-name="filter-job-item" data-path=".job-item" id="search-keywords-2" name="keywords" placeholder="Search jobs" type="text" value=""/>
#             </div>
#            </div>
#           </div>
#           <div class="mod_filternavigation navigation block">
#            <input class="checkbox hidden" id="toggle_filternav" name="toggle_filternav" type="checkbox" value="1"/>
#            <label class="filternav__toggler" for="toggle_filternav">
#             Filter
#            </label>
#            <div class="filternav__content">
#             <div class="tab__item tab__item-default mt-5">
#              <div class="box-select">
#               <div class="item toggle-item">
#                <div class="legend-container">
#                 <legend>
#                  Entry level
#                 </legend>
#                </div>
#                <div class="filternav__selection" id="entrylevel">
#                 <ul class="scrollable-dropdown-list">
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Experienced professional" data-jplist-control="checkbox-text-filter" data-name="filter-entrylevel" data-or="entrylevel" data-path=".entrylevel" data-text="Experienced professional" id="level-1-filter" name="entrylevel[]" type="checkbox" value="Experienced professional">
#                    <label for="level-1-filter" id="label_level-1">
#                     <span class="label-name">
#                      Experienced professional
#                     </span>
#                    </label>
#                   </input>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Graduates" data-jplist-control="checkbox-text-filter" data-name="filter-entrylevel" data-or="entrylevel" data-path=".entrylevel" data-text="Graduates" id="level-2-filter" name="entrylevel[]" type="checkbox" value="Graduates">
#                    <label for="level-2-filter" id="label_level-2">
#                     <span class="label-name">
#                      Graduates
#                     </span>
#                    </label>
#                   </input>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Pupils" data-jplist-control="checkbox-text-filter" data-name="filter-entrylevel" data-or="entrylevel" data-path=".entrylevel" data-text="Pupils" id="level-3-filter" name="entrylevel[]" type="checkbox" value="Pupils"/>
#                   <label for="level-3-filter" id="label_level-3">
#                    <span class="label-name">
#                     Pupils
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Students" data-jplist-control="checkbox-text-filter" data-name="filter-entrylevel" data-or="entrylevel" data-path=".entrylevel" data-text="Students" id="level-4-filter" name="entrylevel[]" type="checkbox" value="Students"/>
#                   <label for="level-4-filter" id="label_level-4">
#                    <span class="label-name">
#                     Students
#                    </span>
#                   </label>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="item toggle-item">
#                <div class="legend-container">
#                 <legend>
#                  Field
#                 </legend>
#                </div>
#                <div class="filternav__selection" id="jobarea">
#                 <ul class="scrollable-dropdown-list">
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="ProjectManagement" data-jplist-control="checkbox-text-filter" data-name="filter-ProjectManagement" data-or="jobarea" data-path=".jobarea" data-text="Project Management" id="area-ProjectManagement-filter" name="jobarea[]" type="checkbox" value="Project Management"/>
#                   <label for="area-ProjectManagement-filter" id="label_area-ProjectManagement">
#                    <span class="label-name">
#                     Project Management
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Consulting" data-jplist-control="checkbox-text-filter" data-name="filter-Consulting" data-or="jobarea" data-path=".jobarea" data-text="Consulting" id="area-Consulting-filter" name="jobarea[]" type="checkbox" value="Consulting"/>
#                   <label for="area-Consulting-filter" id="label_area-Consulting">
#                    <span class="label-name">
#                     Consulting
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Planning" data-jplist-control="checkbox-text-filter" data-name="filter-Planning" data-or="jobarea" data-path=".jobarea" data-text="Planning" id="area-Planning-filter" name="jobarea[]" type="checkbox" value="Planning"/>
#                   <label for="area-Planning-filter" id="label_area-Planning">
#                    <span class="label-name">
#                     Planning
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="ConstructionManagement" data-jplist-control="checkbox-text-filter" data-name="filter-ConstructionManagement" data-or="jobarea" data-path=".jobarea" data-text="Construction Management" id="area-ConstructionManagement-filter" name="jobarea[]" type="checkbox" value="Construction Management"/>
#                   <label for="area-ConstructionManagement-filter" id="label_area-ConstructionManagement">
#                    <span class="label-name">
#                     Construction Management
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="WorkplaceConsulting" data-jplist-control="checkbox-text-filter" data-name="filter-Workplace Consulting" data-or="jobarea" data-path=".jobarea" data-text="Workplace Consulting" id="area-WorkplaceConsulting-filter" name="jobarea[]" type="checkbox" value="Workplace Consulting"/>
#                   <label for="area-WorkplaceConsulting-filter" id="label_area-WorkplaceConsulting">
#                    <span class="label-name">
#                     Workplace Consulting
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="EngineeringConsulting" data-jplist-control="checkbox-text-filter" data-name="filter-EngineeringConsulting" data-or="jobarea" data-path=".jobarea" data-text="Engineering Consulting" id="area-EngineeringConsulting-filter" name="jobarea[]" type="checkbox" value="Engineering Consulting"/>
#                   <label for="area-EngineeringConsulting-filter" id="label_area-EngineeringConsulting">
#                    <span class="label-name">
#                     Engineering Consulting
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="SmartInfrastructure" data-jplist-control="checkbox-text-filter" data-name="filter-SmartInfrastructure" data-or="jobarea" data-path=".jobarea" data-text="Smart Infrastructure" id="area-SmartInfrastructure-filter" name="jobarea[]" type="checkbox" value="Smart Infrastructure"/>
#                   <label for="area-SmartInfrastructure-filter" id="label_area-SmartInfrastructure">
#                    <span class="label-name">
#                     Smart Infrastructure
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="RealEstateConsulting" data-jplist-control="checkbox-text-filter" data-name="filter-RealEstateConsulting" data-or="jobarea" data-path=".jobarea" data-text="Real Estate Consulting" id="area-RealEstateConsulting-filter" name="jobarea[]" type="checkbox" value="Real Estate Consulting"/>
#                   <label for="area-RealEstateConsulting-filter" id="label_area-RealEstateConsulting">
#                    <span class="label-name">
#                     Real Estate Consulting
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="StructuralEngineering" data-jplist-control="checkbox-text-filter" data-name="filter-StructuralEngineering" data-or="jobarea" data-path=".jobarea" data-text="Structural Engineering" id="area-StructuralEngineering-filter" name="jobarea[]" type="checkbox" value="Structural Engineering"/>
#                   <label for="area-StructuralEngineering-filter" id="label_area-StructuralEngineering">
#                    <span class="label-name">
#                     Structural Engineering
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="BusinessDevelopment" data-jplist-control="checkbox-text-filter" data-name="filter-Business Development" data-or="jobarea" data-path=".jobarea" data-text="Business Development/Sales" id="area-BusinessDevelopment-filter" name="jobarea[]" type="checkbox" value="Business Development/Sales"/>
#                   <label for="area-BusinessDevelopment-filter" id="label_area-BusinessDevelopment">
#                    <span class="label-name">
#                     Business Development/Sales
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Assistance" data-jplist-control="checkbox-text-filter" data-name="filter-Assistance" data-or="jobarea" data-path=".jobarea" data-text="Assistance" id="area-Assistance-filter" name="jobarea[]" type="checkbox" value="Assistance"/>
#                   <label for="area-Assistance-filter" id="label_area-Assistance">
#                    <span class="label-name">
#                     Assistance
#                    </span>
#                   </label>
#                  </li>
#                  <li>
#                   <input class="checkbox hidden" data-group="jobs" data-id="Finance" data-jplist-control="checkbox-text-filter" data-name="filter-Finance" data-or="jobarea" data-path=".jobarea" data-text="Finance" id="area-Finance-filter" name="jobarea[]" type="checkbox" value="Finance"/>
#                   <label for="area-Finance-filter" id="label_area-Finance">
#                    <span class="label-name">
#                     Finance
#                    </span>
#                   </label>
#                  </li>
#                  <li>
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                  " data-result="filter-result" data-timelimit="
#                                                     Full-time and Part-time" data-title="Chef de Projet Senior en AMO (F/H)">
#               <td class="title job-item">
#                <a href="https://recruitingapp-5045.de.umantis.com/Vacancies/8849/Description/3?lang=fre" rel="noopener noreferrer" target="_blank">
#                 Chef de Projet Senior en AMO (F/H)
#                </a>
#               </td>
#               <td class="jobarea job-item">
#                Project Management
#               </td>
#               <td class="country job-item">
#                France
#               </td>
#               <td class="city job-item">
#                Paris
#               </td>
#               <td class="timelimit job-item">
#                Full-time
#               </td>
#               <td class="corporate-group job-item">
#                Drees &amp; Sommer
#               </td>
#               <td class="region job-item" style="display:none;">
#               </td>
#               <td class="city-2 job-item" style="display:none;">
#                Paris
#               </td>
#               <td class="reults job-item" style="display:none;">
#                filter result
#               </td>
#               <td class="entrylevel job-item">
#                Experienced professional
#               </td>
#              </tr>
#              <tr data-city="Paris" data-corporate-group="Drees &amp; Sommer" data-country="France" data-entrylevel="Experienced professional" data-jobarea="Project Management | Engineering Consulting" data-jplist-item="" data-region="
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                  " data-result="filter-result" data-timelimit="
#                                                     Full-time and Part-time" data-title="Ingénieur fluides / CVCD (F/H)">
#               <td class="title job-item">
#                <a href="https://recruitingapp-5045.de.umantis.com/Vacancies/8848/Description/3?lang=fre" rel="noopener noreferrer" target="_blank">
#                 Ingénieur fluides / CVCD (F/H)
#                </a>
#               </td>
#               <td class="jobarea job-item">
#                Project Management | Engineering Consulting
#               </td>
#               <td class="country job-item">
#                France
#               </td>
#               <td class="city job-item">
#                Paris
#               </td>
#               <td class="timelimit job-item">
#                Full-time
#               </td>
#               <td class="corporate-group job-item">
#                Drees &amp; Sommer
#               </td>
#               <td class="region job-item" style="display:none;">
#               </td>
#               <td class="city-2 job-item" style="display:none;">
#                Paris
#               </td>
#               <td class="reults job-item" style="display:none;">
#                filter result
#               </td>
#               <td class="entrylevel job-item">
#                Experienced professional
#               </td>
#              </tr>
#              <tr data-city="Lausanne" data-corporate-group="Drees &amp; Sommer" data-country="Switzerland" data-entrylevel="Experienced professional" data-jobarea="Project Management" data-jplist-item="" data-region="
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                  " data-result="filter-result" data-timelimit="
#                                                     Full-time and Part-time" data-title="Chef de Projet ( AMO/RMO) (f/h) à 100%">
#               <td class="title job-item">
#                <a href="https://recruitingapp-5045.de.umantis.com/Vacancies/8521/Description/3?lang=fre" rel="noopener noreferrer" target="_blank">
#                 Chef de Projet ( AMO/RMO) (f/h) à 100%
#                </a>
#               </td>
#               <td class="jobarea job-item">
#                Project Management
#               </td>
#               <td class="country job-item">
#                Switzerland
#               </td>
#               <td class="city job-item">
#                Lausanne
#               </td>
#               <td class="timelimit job-item">
#                Full-time
#               </td>
#               <td class="corporate-group job-item">
#                Drees &amp; Sommer
#               </td>
#               <td class="region job-item" style="display:none;">
#               </td>
#               <td class="city-2 job-item" style="display:none;">
#                Lausanne
#               </td>
#               <td class="reults job-item" style="display:none;">
#                filter result
#               </td>
#               <td class="entrylevel job-item">
#                Experienced professional
#               </td>
#              </tr>
#              <tr data-city="Paris" data-corporate-group="Drees &amp; Sommer" data-country="France" data-entrylevel="Experienced professional" data-jobarea="Business Development/Sales" data-jplist-item="" data-region="
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                  " data-result="filter-result" data-timelimit="
#                                                     Full-time and Part-time" data-title="Business Development Manager (F/H) dans le domaine des bâtiments industriels et des solutions immobilières">
#               <td class="title job-item">
#                <a href="https://recruitingapp-5045.de.umantis.com/Vacancies/8547/Description/3?lang=fre" rel="noopener noreferrer" target="_blank">
#                 Business Development Manager (F/H) dans le domaine des bâtiments industriels et des solutions immobilières
#                </a>
#               </td>
#               <td class="jobarea job-item">
#                Business Development/Sales
#               </td>
#               <td class="country job-item">
#                France
#               </td>
#               <td class="city job-item">
#                Paris
#               </td>
#               <td class="timelimit job-item">
#                Full-time
#               </td>
#               <td class="corporate-group job-item">
#                Drees &amp; Sommer
#               </td>
#               <td class="region job-item" style="display:none;">
#               </td>
#               <td class="city-2 job-item" style="display:none;">
#                Paris
#               </td>
#               <td class="reults job-item" style="display:none;">
#                filter result
#               </td>
#               <td class="entrylevel job-item">
#                Experienced professional
#               </td>
#              </tr>
#              <!-- no results control -->
#              <tr class="no-results-all" data-group="jobs" data-jplist-control="no-results" data-name="no-results">
#               <td colspan="6">
#                Unfortunately, we currently have no vacancies matching your search criteria. You are welcome to send us an
#                <a href="https://recruitingapp-5045.de.umantis.com/Vacancies/InitiativeApplication/31?lang=eng" target="_blank">
#                 unsolicited application
#                </a>
#                or subscribe to our
#                <a href="https://recruitingapp-5045.de.umantis.com/Vacancies/Register/31" target="_blank">
#                 job alert
#                </a>
#                .
#               </td>
#               <td>
#               </td>
#              </tr>
#             </tbody>
#            </table>
#           </div>
#          </div>
#         </div>
#        </section>
#       </div>
#      </div>
#     </div>
#    </section>
#   </main>
#   <!--TYPO3SEARCH_end-->
#   <footer id="footer">
#    <div id="toTop-navigation">
#     <button id="toTop">
#      <span>
#       <span class="top">
#        <em>
#         back to
#        </em>
#        Top
#       </span>
#      </span>
#     </button>
#    </div>
#    <div id="footer-navigation">
#     <nav class="navigation" id="footer-main-navigation">
#      <!--            <ul class="level_1">-->
#      <!--                <li class="level_1"><a class="level_1 dreso-plus" href="/de/en/dreso"></a></li>-->
#      <!--            </ul>-->
#      <ul class="level_1">
#       <li class="level_1">
#        <a href="/de/en/aspiration">
#         Aspiration
#        </a>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/sectors">
#         Sectors
#        </a>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/news">
#         News
#        </a>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/projects">
#         Projects
#        </a>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/company">
#         Company
#        </a>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/career">
#         Career
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav class="navigation" id="footer-meta-navigation">
#      <ul class="first-menu">
#       <li class="level_1">
#        <a href="/de/en/company/press">
#         Press
#        </a>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/contact">
#         Contact
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <div class="navigation" id="copyright">
#      <ul>
#       <li class="level_1">
#        <a href="/de/en/privacy-policy">
#         Privacy policy
#        </a>
#       </li>
#       <li class="level_1">
#        <button onclick="UC_UI.showSecondLayer();">
#         Cookie Settings
#        </button>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/legal-notice">
#         Legal notice
#        </a>
#       </li>
#       <li class="level_1">
#        <a href="/de/en/sitemap">
#         Copyright © 2020 Drees &amp; Sommer | Sitemap
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <nav class="navigation" id="footer-social-navigation">
#     <div class="social">
#      <span class="h6 headline">
#       Follow us
#      </span>
#      <ul>
#       <li>
#        <a class="icon-xing" href="https://www.xing.com/companies/dreesundsommer" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a class="icon-linkedin" href="https://www.linkedin.com/company/drees-&amp;-sommer" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a class="icon-youtube" href="https://www.youtube.com/channel/UCsGLLBudvpi0TRvRaX0x0zg" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a class="icon-instagram" href="https://www.instagram.com/drees_sommer/" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a class="icon-twitter" href="https://twitter.com/drees_sommer" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a class="icon-vimeo" href="https://vimeo.com/user55605773" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a class="icon-blog" href="https://dreso-blog.de/" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a class="icon-podcast" href="/de/en/landing-pages/podcast">
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#   </footer>
#   <script src="/typo3temp/assets/compressed/merged-f3df97895aadf7a26511e360d2ec9bf4-2f5e345442d2ee2a27fb330988720614.js?1628060639" type="text/javascript">
#   </script>
#   <script src="/typo3temp/assets/compressed/merged-dd88b0f935c3028853eabfb0a64efe60-faae2d883abc4a568edbfb3642ffcbfc.js?1649831937" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
# In[25]:


job_id_line = soup.find_all('td', 'title job-item')
print(len(job_id_line))
job_id_line[0]
# Out:
# 866
# <td class="title job-item"><a href="https://recruitingapp-5045.de.umantis.com/Vacancies/9192/Description/31?lang=gerger" rel="noopener noreferrer" target="_blank">Innenarchitekt / Architekt (w/m/d) als Projektleiter im Workplaceconsulting</a></td>

# %%
# In[31]:

job_ids=[]
import re
for i in range(len(job_id_line)):
    job_id_each=re.search('Vacancies/(\d+)/Description', str(job_id_line[i]))[1]
    job_ids.append(job_id_each)

# %%
df['Job ID']=job_ids
df.rename(columns = {'Entry level':'Job_tittle', 'Time limit':'Full_or_part_time','Entry as':'level_of_seniority','Job ID':'Job_ID'}, inplace = True)

# %%
df.head()
# Out:
#                                           Job_tittle  \
# 1  Innenarchitekt / Architekt (w/m/d) als Projekt...
# 2  Architekt/Innenarchitekt (w/m/d) als Teamlead ...
# 3                   Praktikant (w/m/d) Baumanagement
# 4              Teamassistenz (w/m/d) User Experience
# 5  Ingenieur (w/m/d) für Energiedesign, CO₂-Optim...
#
#                                           Field  Country               City  \
# 1  Workplace Consulting | Consulting | Planning  Germany          Frankfurt
# 2  Workplace Consulting | Consulting | Planning  Germany  Baden-Württemberg
# 3                       Construction Management  Germany             Munich
# 4             Workplace Consulting | Assistance  Germany          Stuttgart
# 5                        Engineering Consulting  Germany          Stuttgart
#
#          Full_or_part_time Corporate group        level_of_seniority Job_ID
# 1  Full-time and Part-time  Drees & Sommer  Experienced professional   9192
# 2                Full-time  Drees & Sommer  Experienced professional   8623
# 3                Full-time  Drees & Sommer                  Students   8555
# 4                Full-time  Drees & Sommer  Experienced professional   8883
# 5                Full-time  Drees & Sommer  Experienced professional   9223

# %%
df1=df[["Job_ID","Job_tittle","Country","City","Field","level_of_seniority","Full_or_part_time","Corporate group"]]
df1
# Out:
#     Job_ID                                         Job_tittle      Country  \
# 1     9192  Innenarchitekt / Architekt (w/m/d) als Projekt...      Germany
# 2     8623  Architekt/Innenarchitekt (w/m/d) als Teamlead ...      Germany
# 3     8555                   Praktikant (w/m/d) Baumanagement      Germany
# 4     8883              Teamassistenz (w/m/d) User Experience      Germany
# 5     9223  Ingenieur (w/m/d) für Energiedesign, CO₂-Optim...      Germany
# ..     ...                                                ...          ...
# 862   8723  Stagiaire (f/h) consultant Workplace & Facilit...  Switzerland
# 863   8849                 Chef de Projet Senior en AMO (F/H)       France
# 864   8848                     Ingénieur fluides / CVCD (F/H)       France
# 865   8521             Chef de Projet ( AMO/RMO) (f/h) à 100%  Switzerland
# 866   8547  Business Development Manager (F/H) dans le dom...       France
#
#                   City                                         Field  \
# 1            Frankfurt  Workplace Consulting | Consulting | Planning
# 2    Baden-Württemberg  Workplace Consulting | Consulting | Planning
# 3               Munich                       Construction Management
# 4            Stuttgart             Workplace Consulting | Assistance
# 5            Stuttgart                        Engineering Consulting
# ..                 ...                                           ...
# 862           Lausanne                        Real Estate Consulting
# 863              Paris                            Project Management
# 864              Paris   Project Management | Engineering Consulting
# 865           Lausanne                            Project Management
# 866              Paris                    Business Development/Sales
#
#            level_of_seniority        Full_or_part_time Corporate group
# 1    Experienced professional  Full-time and Part-time  Drees & Sommer
# 2    Experienced professional                Full-time  Drees & Sommer
# 3                    Students                Full-time  Drees & Sommer
# 4    Experienced professional                Full-time  Drees & Sommer
# 5    Experienced professional                Full-time  Drees & Sommer
# ..                        ...                      ...             ...
# 862                  Students                Full-time  Drees & Sommer
# 863  Experienced professional                Full-time  Drees & Sommer
# 864  Experienced professional                Full-time  Drees & Sommer
# 865  Experienced professional                Full-time  Drees & Sommer
# 866  Experienced professional                Full-time  Drees & Sommer
#
# [866 rows x 8 columns]

# %%
df1.to_excel('/Users/palakawasthi/Downloads/Dresso/Dresso.xlsx',index=False)
